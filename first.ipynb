# %%
import numpy as np


import matplotlib.pyplot as plt

# %%
path = "/users/binayamaharjan/machinelearning/"

# %%
import os
os.listdir(path)
# Out:
# ['download.jpeg',
#  '.DS_Store',
#  'env',
#  'first.ipynb',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  '.git']

# %%
from matplotlib.image import imread

# %%
image = path + 'download.jpeg'

# %%
imread(image)
# Out:
# array([[[29, 29, 29],
#         [35, 35, 35],
#         [42, 42, 42],
#         ...,
#         [66, 66, 66],
#         [66, 66, 66],
#         [66, 66, 66]],
#
#        [[31, 31, 31],
#         [36, 36, 36],
#         [43, 43, 43],
#         ...,
#         [65, 65, 65],
#         [65, 65, 65],
#         [65, 65, 65]],
#
#        [[32, 32, 32],
#         [38, 38, 38],
#         [45, 45, 45],
#         ...,
#         [65, 65, 65],
#         [65, 65, 65],
#         [65, 65, 65]],
#
#        ...,
#
#        [[49, 49, 49],
#         [47, 47, 47],
#         [44, 44, 44],
#         ...,
#         [30, 30, 30],
#         [31, 31, 31],
#         [31, 31, 31]],
#
#        [[54, 54, 54],
#         [52, 52, 52],
#         [50, 50, 50],
#         ...,
#         [30, 30, 30],
#         [30, 30, 30],
#         [30, 30, 30]],
#
#        [[61, 61, 61],
#         [59, 59, 59],
#         [56, 56, 56],
#         ...,
#         [29, 29, 29],
#         [29, 29, 29],
#         [30, 30, 30]]], dtype=uint8)

# %%
imread(image).shape
# Out:
# (195, 259, 3)

# %%
from PIL import Image

# %%
im = Image.open(image)
im = im.crop( (1, 0, 200, 200) ) 
im.save('card.png') # saves the image
plt.imshow(imread('card.png')) # opens the image

# %%
plt.imshow(imread(image))

# %%
imread('card.png')
# Out:
# array([[[0.13725491, 0.13725491, 0.13725491],
#         [0.16470589, 0.16470589, 0.16470589],
#         [0.18039216, 0.18039216, 0.18039216],
#         ...,
#         [0.24705882, 0.24705882, 0.24705882],
#         [0.28235295, 0.28235295, 0.28235295],
#         [0.3019608 , 0.3019608 , 0.3019608 ]],
#
#        [[0.14117648, 0.14117648, 0.14117648],
#         [0.16862746, 0.16862746, 0.16862746],
#         [0.1882353 , 0.1882353 , 0.1882353 ],
#         ...,
#         [0.28235295, 0.28235295, 0.28235295],
#         [0.30980393, 0.30980393, 0.30980393],
#         [0.3254902 , 0.3254902 , 0.3254902 ]],
#
#        [[0.14901961, 0.14901961, 0.14901961],
#         [0.1764706 , 0.1764706 , 0.1764706 ],
#         [0.19607843, 0.19607843, 0.19607843],
#         ...,
#         [0.34117648, 0.34117648, 0.34117648],
#         [0.35686275, 0.35686275, 0.35686275],
#         [0.36078432, 0.36078432, 0.36078432]],
#
#        ...,
#
#        [[0.        , 0.        , 0.        ],
# ...
